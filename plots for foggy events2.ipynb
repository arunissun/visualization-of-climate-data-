# %%
#importing modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import DayLocator, HourLocator,DateFormatter
import datetime as dt
import warnings

# %%
#visibility 10 
#reading the omsz data
omsz_path = '/Volumes/Seagate Backup Plus Drive/data_1/Data_OMSZ_10min.pkl'
df = pd.read_pickle(omsz_path)

# %%
df['idő (UTC)'] = pd.to_datetime(df['idő (UTC)'])

# %%
n_d = df[(df['idő (UTC)'] >= '2020-11-20 16:22:00') & (df['idő (UTC)'] <= '2020-12-31 23:59:00')]
j_m = df[(df['idő (UTC)'] >= '2021-01-01 00:00:00') & (df['idő (UTC)'] <= '2021-03-11 13:13:00')]

# %%
### for time intervals of fog for nov to dec
## 24 nov fog
##240 minutes added 
t_1 = 333
t_2 = 730
time_1 = n_d['idő (UTC)'][t_1:t_2] 
a_0 = n_d['idő (UTC)'][498:499] #fog
a_1 = n_d['idő (UTC)'][532:533] #fog
b_0 = n_d['idő (UTC)'][511:512] #fog
b_1 = n_d['idő (UTC)'][612:613] #fog

#c = n_d['TIMESTAMP_UTC'][4988+1137+1]   #rain
#d = n_d['TIMESTAMP_UTC'][4988+1137+1180]  #rain

##29 nov fog
t_3 = 1101
t_4 = 1300
time_2 = n_d['idő (UTC)'][t_3:t_4]
a_2 =  n_d['idő (UTC)'][1204:1205]
b_2 =  n_d['idő (UTC)'][1219:1220]
#print(time1,time2)
#time1
#2020-11-23 00:00:00, 2020-11-25 18:01:00
print(time_2)
# Out:
# 8405   2020-11-28 08:00:00
# 8406   2020-11-28 08:10:00
# 8407   2020-11-28 08:20:00
# 8408   2020-11-28 08:30:00
# 8409   2020-11-28 08:40:00
#                ...
# 8599   2020-11-29 16:20:00
# 8600   2020-11-29 16:30:00
# 8601   2020-11-29 16:40:00
# 8602   2020-11-29 16:50:00
# 8603   2020-11-29 17:00:00
# Name: idő (UTC), Length: 199, dtype: datetime64[ns]

# %%
#foggy periods of jan and feb in consideration
#foggy period of jan 12
##no adding 240 minutes 
t_7 = 1494
t_8 = 1651
time_4 = j_m['idő (UTC)'][t_7:t_8]

y_1 = j_m['idő (UTC)'][1609:1610]
y_2 = j_m['idő (UTC)'][1630:1631]

##longest foggy periods of feb 02
t_9 = 4650
t_10= 4855
time_5 = j_m['idő (UTC)'][t_9:t_10]
y_3 = j_m['idő (UTC)'][4709:4710]
y_4 = j_m['idő (UTC)'][4818:4819]


##foggy period of feb 20
t_11 = 7104
t_12 = 7321
time_6= j_m['idő (UTC)'][t_11:t_12]
#y_5 = j_m['TIMESTAMP_UTC'][72230]
#y_6 = j_m['TIMESTAMP_UTC'][72230+240]

print(time_6)
# Out:
# 20357   2021-02-19 08:00:00
# 20358   2021-02-19 08:10:00
# 20359   2021-02-19 08:20:00
# 20360   2021-02-19 08:30:00
# 20361   2021-02-19 08:40:00
#                 ...
# 20569   2021-02-20 19:20:00
# 20570   2021-02-20 19:30:00
# 20571   2021-02-20 19:40:00
# 20572   2021-02-20 19:50:00
# 20573   2021-02-20 20:00:00
# Name: idő (UTC), Length: 217, dtype: datetime64[ns]

# %%
# %matplotlib inline
fig, ax1 = plt.subplots(1,1,figsize = (25,8),sharex= False)

ax1.axvspan(a_0, b_0, color='y', alpha=0.5, lw=0)
ax1.axvspan(a_1, b_1, color='y', alpha=0.5, lw=0)


ax1.scatter(time_1,  n_d['V'][t_1:t_2], label = 'visibility', color = 'r', marker = 'o')
ax1.set_yscale('log') 
ax1.set_ylim([0,10**4])
ax1.set_yticks([100,1000,10000])
ax1.set_yticklabels(['$10^2$','$10^3$','$10^4$'])
ax1.minorticks_on()
ax1.tick_params(axis='both', which='major', labelsize=22)
ax1.tick_params(axis='both', which='minor', labelsize=10)
ax1.tick_params(axis='x', labelrotation= 15)
ax1.xaxis.set_major_formatter(DateFormatter("%m-%d %H"))
ax1.xaxis.set_major_locator(HourLocator(interval= 6))
# Out:
# /Applications/miniconda3/envs/icclim/lib/python3.8/site-packages/matplotlib/patches.py:1111: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   xy = np.asarray(xy)
# /var/folders/lj/42kjq4jj2lj80_y4pkyqbcwh0000gn/T/ipykernel_5883/1821922421.py:10: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax1.set_ylim([0,10**4])

# %%
fig, ax1 = plt.subplots(1,1,figsize = (25,8),sharex= False)

ax1.axvspan(a_2, b_2, color='y', alpha=0.5, lw=0)
#ax1.axvspan(a1, b1, color='y', alpha=0.5, lw=0)


ax1.plot(time_2,  n_d['V'][t_3:t_4], label = 'visibility', color = 'r', marker = 'o')
ax1.set_yscale('symlog') 
ax1.set_yticks([1000,10000, 2* 10**4])
ax1.set_yticklabels(['$10^3$','$10^4$', '$2*10^4$'])
ax1.tick_params(axis='both', which='major', labelsize=22)
ax1.tick_params(axis='both', which='minor', labelsize=10)
ax1.tick_params(axis='x', labelrotation= 15)
ax1.xaxis.set_major_formatter(DateFormatter("%m-%d %H"))
ax1.xaxis.set_major_locator(HourLocator(interval= 6))
# Out:
# /Applications/miniconda3/envs/icclim/lib/python3.8/site-packages/matplotlib/patches.py:1111: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   xy = np.asarray(xy)

# %%
fig, ax1 = plt.subplots(1,1,figsize = (25,8),sharex= False)

ax1.axvspan(y_1, y_2, color='y', alpha=0.5, lw=0)
#ax1.axvspan(a1, b1, color='y', alpha=0.5, lw=0)


ax1.plot(time_4,  j_m['V'][t_7:t_8], label = 'visibility', color = 'r', marker = 'o')
ax1.set_yscale('log') 
ax1.set_yticks([100,1000,10000])
ax1.set_yticklabels(['$10^2$','$10^3$', '$10^4$'])
ax1.tick_params(axis='both', which='major', labelsize=22)
ax1.tick_params(axis='both', which='minor', labelsize=10)
ax1.tick_params(axis='x', labelrotation= 15)
ax1.xaxis.set_major_formatter(DateFormatter("%m-%d %H"))
ax1.xaxis.set_major_locator(HourLocator(interval= 6))
# Out:
# /Applications/miniconda3/envs/icclim/lib/python3.8/site-packages/matplotlib/patches.py:1111: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   xy = np.asarray(xy)

# %%
#u star and sigma w is 30 minutes
