# %%
import numpy as np
import pandas as pd
import regex as re
import matplotlib.pyplot as plt

# %%
file= open('/Users/varungandhi/Downloads/regexexamples.md').read()

# %%
file
# Out:
# "'hello' darkness my old 'friend'\n\nToday is 23rd May 2021, but tomorrow is 24th May.\n\njasf23 asdfas344\nklhd=54 elsjdhf=30 saeldjfh=90\nlsha=9 jdhna=3 sdsdfajajf=20\nlhas=10\nlhad=20 asdefafd= sdfl\n\n# def func():\n# def func2():\ndef func3():\n\ndef func4():\n\nbence@ferdinandy.com\nururi48393@93jdf7dkk.hu\n&@%+!@gmail.com\n\n12-10-2021 pqwuezr 10-30-2020\n\n\nI wish you a happy happy birthday!\n\nThis is one sentence. I really like this book. And this is another sentence. This code is very very bad.\n\n<h1> header </h1> \n\nThis is now in <b>bold</b> *italic* and **bold** again but sometime we have\njust a simple <tag/> .\n\n\nAwesooome\nCoool\n\nfile1.txt file2.txt file3.dat file4.Rmd file5.Rmd\n"

# %%
re.search(r'#\sdef',file)
# Out:
# <regex.Match object; span=(194, 199), match='# def'>

# %%
re.findall(r'(\w+)=(\d+)',file)
# Out:
# [('klhd', '54'),
#  ('elsjdhf', '30'),
#  ('saeldjfh', '90'),
#  ('lsha', '9'),
#  ('jdhna', '3'),
#  ('sdsdfajajf', '20'),
#  ('lhas', '10'),
#  ('lhad', '20')]

# %%
re.findall(r'(def)\s(func\d)',file)
# Out:
# [('def', 'func2'), ('def', 'func3'), ('def', 'func4')]

# %%
re.findall(r'(def)\s(func\d)',file)
# Out:
# [('def', 'func2'), ('def', 'func3'), ('def', 'func4')]

# %%
re.findall(r'(\d{2})-(\d{2})-(\d{4})',file)
# Out:
# [('12', '10', '2021'), ('10', '30', '2020')]

# %%
re.findall(r'(\d{2})-(\d{2})-(\d{4})',file)
# Out:
# [('12', '10', '2021'), ('10', '30', '2020')]

# %%
file2 = pd.read_csv('/Users/varungandhi/Downloads/flat_data_file.dat',sep= ',')

# %%
x = file2['# time'].values
y = file2['user_acceleration_y'].values

# %%
plt.plot(x,y)

# %%
time = file2['# time'][::2]
acc_y = file2['user_acceleration_y'][::2]

# %%
plt.plot(time, acc_y)

# %%
time = file2['# time'][190:300]
acc_y = file2['user_acceleration_y'][190:300]

# %%
plt.plot(time, acc_y)
