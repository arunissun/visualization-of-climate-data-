# %%
import pandas

# %%
import icclim

# %%
import datetime

# %%
cd /Users/varungandhi/Downloads
# Out:
# /Users/varungandhi/Downloads

# %%
files = ['tasmax_day_CNRM-CM5_historical_r1i1p1_20050101-20051231.nc']
dt1 = datetime.datetime(2005,1,1)

dt2 = datetime.datetime(2005,12,31)

out_f = 'SU_JJA_CNRM-CM5_historical_r1i1p1_1998-2005.nc' # OUTPUT FILE: summer season values of SU

icclim.indice(indice_name='SU', in_files=files, var_name='tasmax', time_range=[dt1, dt2], slice_mode='JJA', out_file=out_f)
# Out:
# 2021-12-29 15:01:20,608 DEPRECATION_WARNING: `icclim.indice` is deprecated. Use `icclim.index` instead.
# 2021-12-29 15:01:20,612 --- Icclim 5.0.0rc2
# 2021-12-29 15:01:20,616 --- BEGIN EXECUTION
# 2021-12-29 15:01:20,618 Processing: 0%
# 2021-12-29 15:01:20,620 DEPRECATION_WARNING: `indice_name` is deprecated. Use `index_name` instead.
# 2021-12-29 15:01:20,682 Calculating climate index: SU
# 2021-12-29 15:01:21,340 Processing: 100%
# 2021-12-29 15:01:21,342 --- Icclim 5.0.0rc2
# 2021-12-29 15:01:21,343 --- CPU SECS = 5.036
# 2021-12-29 15:01:21,346 --- END EXECUTION
# <xarray.Dataset>
# Dimensions:      (lat: 128, lon: 256, time: 1, bounds: 2)
# Coordinates:
#   * lat          (lat) float64 -88.93 -87.54 -86.14 -84.74 ... 86.14 87.54 88.93
#   * lon          (lon) float64 0.0 1.406 2.812 4.219 ... 354.4 355.8 357.2 358.6
#     height       float64 2.0
#   * time         (time) datetime64[ns] 2005-07-16T12:00:00
#   * bounds       (bounds) int64 0 1
# Data variables:
#     SU           (time, lat, lon) float64 dask.array<chunksize=(1, 128, 256), meta=np.ndarray>
#     time_bounds  (time, bounds) datetime64[ns] 2005-06-01 2005-08-31
# Attributes:
#     title:        ECA heat index SU
#     references:   ATBD of the ECA indices calculation (https://www.ecad.eu/do...
#     institution:  Climate impact portal (https://climate4impact.eu)
#     history:      2011-04-07T18:05:05Z CMOR rewrote data to comply with CF st...
#     source:
#     Conventions:  CF-1.6
